# %% [markdown]
# Coding Exercise 1 - Variables and numbers

# %%
# Create two variables, var1 and var2, both with the same value.
var1 = var2 = 3
# Create two variables, num1 and num2, which multiply together to give 16.
num1 = 8 
num2 = 2 
mult = num1*num2

# %% [markdown]
# Coding Exercise 2 - Communicating with user

# %%
# First, ask the user for their name. Then, print out the greeting "Hello, NAME"
# Remember the uppercase H, the comma, and the space between words!
name = input("Please enter your name")
print(f"Hello, {name}")
# Secondly, ask the user for their age and convert it into a number.
# Then, print out how many months that equals to (you'll have to multiply the age by 12).
age = int(input("What is your age"))
month = age*12
print(month)

# %% [markdown]
# Coding Exercise 3 - nearby friends

# %%
nearby_people = {'Rolf', 'Jen', 'Anna'}
user_friends = set()  # This is an empty set, like {}

# Ask the user for the name of a friend
name = input("Enter your friends name")
# Add the name to the empty set
user_friends.add(name)
# Print out the intersection between both sets. This gives us a set with those friends that are nearby.
inter = user_friends.intersection(nearby_people)
print(inter)

# %% [markdown]
# Coding Exercise 4 - Dictinaries

# %%
lottery_numbers = {13, 21, 22, 5, 8}


"""
A player looks like this:

{
    'name': 'PLAYER_NAME',
    'numbers': {1, 2, 3, 4, 5}
}

Define a list with two players (you can come up with their names and numbers).
"""

players = [
{
    'name': 'Ash',
    'numbers': {10, 20, 30, 40, 50}
},
{
    'name': 'Gary',
    'numbers': {13, 21, 38, 43, 52}
}
]

"""
For each of the two players, print out a string like this: "Player PLAYER_NAME got 3 numbers right.".
Of course, replace PLAYER_NAME by their name, and the 3 by the amount of numbers they matched with lottery_numbers.
You'll have to access each player's name and numbers, and calculate the intersection of their numbers with lottery_numbers.
Then construct a string and print it out.

Remember: the string must contain the player's name and the amount of numbers they got right!
"""
gotright_player1 = len(players[0]['numbers'].intersection(lottery_numbers))
gotright_player2 = len(players[1]['numbers'].intersection(lottery_numbers))

print(f"{players[0]['name']} has got {gotright_player1} correct")
print(f"{players[1]['name']} has got {gotright_player2} correct")
